# %%
import pandas as pd
import numpy as np

# %%
arr=np.array([10,20,30,40,50])
s=pd.Series(arr)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
arr=np.array(['a','b','c','d'])
s=pd.Series(arr,index=['first','second','third','fourth'])
s
# Out:
# first     a
# second    b
# third     c
# fourth    d
# dtype: object

# %%
arr=np.array(['a','b','c','d'])
s=pd.Series(arr,index=['first','second','third','fourth'])
s
# Out:
# first     a
# second    b
# third     c
# fourth    d
# dtype: object

# %%
arr=np.array(['a','b','c','d'])
s=pd.Series(arr,index=['1','2','3','4'])
s
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
s=pd.Series([3,4,5,6,24,35,78])
s
# Out:
# 0     3
# 1     4
# 2     5
# 3     6
# 4    24
# 5    35
# 6    78
# dtype: int64

# %%
s.head(4)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
s.tail()
# Out:
# 2     5
# 3     6
# 4    24
# 5    35
# 6    78
# dtype: int64

# %%
s.loc[0:2]
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
s.iloc[:2]
# Out:
# 0    3
# 1    4
# dtype: int64

# %%
s[:2]
# Out:
# 0    3
# 1    4
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
print(s.index)
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df=pd.DataFrame(s)

# %%
df
# Out:
#     0
# 0   3
# 1   4
# 2   5
# 3   6
# 4  24
# 5  35
# 6  78

# %%
name=pd.Series(['hardik','virat','dhoni'])
team=pd.Series(['mi','rcb'])
df=pd.DataFrame({'name':name,'team':team})
df
# Out:
#      name team
# 0  hardik   mi
# 1   virat  rcb
# 2   dhoni  NaN

# %%
for(row_index,row_value) in df.iterrows():
    print ("row index is:",row_index)
    print ("row value is:",row_value)
# Out:
# row index is: 0
# row value is: name    hardik
# team        mi
# Name: 0, dtype: object
# row index is: 1
# row value is: name    virat
# team      rcb
# Name: 1, dtype: object
# row index is: 2
# row value is: name    dhoni
# team      NaN
# Name: 2, dtype: object

# %%
for(col_index,col_value) in df.items():
    print ("col index is:",col_index)
    print ("col value is:",col_value)
# Out:
# col index is: name
# col value is: 0    hardik
# 1     virat
# 2     dhoni
# Name: name, dtype: object
# col index is: team
# col value is: 0     mi
# 1    rcb
# 2    NaN
# Name: team, dtype: object

# %%
s=pd.Series([20,30,40,50,60])
df=pd.DataFrame(s)
df.columns['list1']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 s=pd.Series([20,30,40,50,60])
#       2 df=pd.DataFrame(s)
# ----> 3 df.columns['list1']
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:832, in RangeIndex.__getitem__(self, key)
#     828         raise IndexError(
#     829             f"index {key} is out of bounds for axis 0 with size {len(self)}"
#     830         ) from err
#     831 elif is_scalar(key):
# --> 832     raise IndexError(
#     833         "only integers, slices (`:`), "
#     834         "ellipsis (`...`), numpy.newaxis (`None`) "
#     835         "and integer or boolean "
#     836         "arrays are valid indices"
#     837     )
#     838 # fall back to Int64Index
#     839 return super().__getitem__(key)
#
# ...
