# %%
import numpy as np
import pandas as pd

# %%
data={'Age':[19,20,24,19,20],
         'Marks':[99, 90, 70, 64, 90]}
df=pd.DataFrame(data)

# %%
df
# Out:
#    Age  Marks
# 0   19     99
# 1   20     90
# 2   24     70
# 3   19     64
# 4   20     90

# %%
df[df.duplicated()]
# Out:
#    Age  Marks
# 4   20     90

# %%
df.drop_duplicates(keep='first')
# Out:
#    Age  Marks
# 0   19     99
# 1   20     90
# 2   24     70
# 3   19     64

# %%
df.drop_duplicates(keep=False)
# Out:
#    Age  Marks
# 0   19     99
# 2   24     70
# 3   19     64

# %%
df.drop_duplicates('Marks')
# Out:
#    Age  Marks
# 0   19     99
# 1   20     90
# 2   24     70
# 3   19     64

# %%
df.drop_duplicates().sum()
# Out:
# Age       82
# Marks    323
# dtype: int64

# %%
df["Age"].unique()
# Out:
# array([19, 20, 24])
