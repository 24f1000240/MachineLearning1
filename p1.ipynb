# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print('''meow''')

# %%
'k'

# %%
word="python is a programming language"
print(word)
print(word[0:6])

# %%
print(word[-1:-9:-1])

# %%
print(word[::-1])

# %%
type(word)

# %%
my_list=[10,'apple',3.14,True]
print(my_list)

# %%
print(my_list[2])
my_list[1]='banana'

# %%
print(my_list[:2])

# %%
my_list.remove(10)
print(my_list)

# %%
my_tuple=(10,'apple',3.14,True)
print(my_tuple)

# %%
for i in range(0,6): print("square of",i,"is",i**2)

# %%
for i in range(0,6): print("cube of",i,"is",i**3)

# %%
for i in range(0,21): 
    if (i%2==0): print(i)

# %%
while True:
    print("False")
    break

# %%
while True:
    i=int(input())
    if i>0: print("+ve")
    else : print("-ve")
    break

# %%
def calculate(a,b):
    print("sum of ",a," and ",b," = ",a+b)
    print("sub of ",a," and ",b," = ",a-b)
    print("mul of ",a," and ",b," = ",a*b)
    if b!=0: print("div of ",a," and ",b," = ",a/b)
    else: print("cannot divide by 0")
calculate(12,0)
