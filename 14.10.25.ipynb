# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=[10,20,30,40]
q1=np.percentile(data,25)
q2=np.percentile(data,50)
q3=np.percentile(data,75)
print("Q1(25%):",q1)
print("Q2(median):",q2)                                                
print("Q3(75%:)",q3)
print("IQR:",q3-q1)
# Out:
# Q1(25%): 17.5
# Q2(median): 25.0
# Q3(75%:) 32.5
# IQR: 15.0

# %%
data=[10,20,30,40,50]
q1=np.percentile(data,25)
q2=np.percentile(data,50)
q3=np.percentile(data,75)
print("Q1(25%):",q1)
print("Q2(median):",q2)
print("Q3(75%:)",q3)
print("IQR:",q3-q1)
# Out:
# Q1(25%): 20.0
# Q2(median): 30.0
# Q3(75%:) 40.0
# IQR: 20.0

# %%
d1=[10,20,30,40]
d2=[10,20,30,40,50]
df1=pd.DataFrame(d1)
df2=pd.DataFrame(d2)

# %%
df1.describe()
# Out:
#                0
# count   4.000000
# mean   25.000000
# std    12.909944
# min    10.000000
# 25%    17.500000
# 50%    25.000000
# 75%    32.500000
# max    40.000000

# %%
df2.describe()
# Out:
#                0
# count   5.000000
# mean   30.000000
# std    15.811388
# min    10.000000
# 25%    20.000000
# 50%    30.000000
# 75%    40.000000
# max    50.000000

# %%
#lines graph
x=[1,2,3,4,5]
y=[10,20,30,40,25]


plt.plot(x,y,color="cyan",linestyle="--",marker='o')


plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple line plot')

plt.grid()
plt.show()

# %%
x=range (-15,16)
y=[x**2 for x in x]

plt.plot(x,y,color="cyan",linestyle="--",marker='o')


plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple line plot')

plt.grid()
plt.show()

# %%
x=range (-15,16)
y=[x**2 for x in x]

plt.plot(x,y,color="black",linewidth=5)
plt.plot(x,y,color="yellow",marker='o')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple line plot')

plt.grid()
plt.show()

# %%
x=range (-15,16)
y=[x**2 for x in x]

plt.plot(x,y,color="green",linewidth=5)
plt.plot(x,y,color="brown",marker='o')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple line plot')

plt.grid()
plt.show()

# %%
x=np.linspace(0,2*np.pi,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,'r',label='sin(x)')
plt.plot(x,y2,'g',label='cos(x)')
plt.xlabel('x axis points',fontweight='bold',fontsize=15)
plt.ylabel('functions',fontweight='bold',fontsize=15)
plt.title('Plotting sin(x) and cos(x)',fontweight='bold')
plt.legend(loc=9)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Data
x = [5, 7, 8, 10, 12, 14, 15]
y = [15, 12, 17, 20, 22, 24, 30]

# Create scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Simple Scatter Plot")

# Display plot
plt.show()

# %%
# Scatter Plot
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(40) # For reproducibility, the same random numbers every time you run the code.42:seed value
X = np.random.rand(100) # 50 random numbers between 0 and 1
Y = np.random.rand(100)
plt.scatter(X, Y, color='cyan', marker='o', s=100, edgecolors='black', alpha=0.5, label='Scatter Plot')
#s-> Sets the marker size.
#edgecolors-> Sets the color of the marker edges.
#alpha-> Adjusts the transparency of the markers.
plt.legend() #position the legend on your plot. Location Code 9-upper center
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = [10, 15, 20, 25, 30]

# Create a box plot
plt.boxplot(data)

# Add title and labels
plt.title("Box Plot Example")
plt.ylabel("Values")

plt.show()

df=pd.DataFrame(data)
print(df.describe())
# Out:
#                0
# count   5.000000
# mean   20.000000
# std     7.905694
# min    10.000000
# 25%    15.000000
# 50%    20.000000
# 75%    25.000000
# max    30.000000

# %%
import matplotlib.pyplot as plt 
import numpy as np
np.random.seed(10) 
d = np.random.normal(100, 20, 200)
fig = plt.figure(figsize =(10, 7)) 
plt.boxplot(d) 
plt.show()

# %%
# Histogram Chart/Plot:
data = [12, 15, 14, 10, 18, 20, 25, 30, 28, 22, 15, 19]

# Create a histogram
plt.hist(data, bins=5, color='cyan', edgecolor='black')

# Add labels and title
plt.title("Histogram of Data")
plt.xlabel("Value Ranges")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
s = pd.Series([1, 3, 2, 5, 7])
s.plot(kind='line', title='Series Plot')
plt.show()

# %%
data = {
    'x': np.arange(1, 6),
    'y': [10, 20, 15, 25, 30]
}

df = pd.DataFrame(data)

# Plot directly from DataFrame
df.plot(x='x', y='y', kind='line', title='Simple Line Plot')

plt.show()

# %%
'''To keep improving their services, XYZ group of hotels have asked all the three hotels 
to get feedback form filled by their customers at the time of checkout. 
After getting ratings on a scale of (1–5) on factors such as Food, Service, Ambience, 
Activities, Distance from tourist spots they calculate the average rating and store it in a CSV file.'''

import pandas as pd
# Create a sample dictionary of 
data = { 'Year': [2014, 2015, 2016, 2017, 2018], 
             'Sunny Bunny Resort': [4.75, 2.5, 3.5, 4, 1.5], 
             'Happy Lucky Resort': [3, 4 , 2.5 , 2 , 4.5], 
             'Breesy Windy Resort': [4.75, 2 , 3 , 3.5 , 1]}
# Convert dictionary to DataFrame
df1 = pd.DataFrame(data)
# Save DataFrame to CSV file
df1.to_csv('Data.csv', index=False)
print("CSV file 'Data.csv' created successfully!")
data1 = pd.read_csv('Data.csv')
df2= pd.DataFrame(data1)
#plot a box plot for the DataFrame 'df' with a title
df2.drop('Year', axis=1).plot(kind='box',title='Compare Resorts')
#set xlabel,ylabel
plt.xlabel('Resorts')
plt.ylabel('Rating (5 years)')
#display the plot
print(df2)
plt.show()
# Out:
# CSV file 'Data.csv' created successfully!
#    Year  Sunny Bunny Resort  Happy Lucky Resort  Breesy Windy Resort
# 0  2014                4.75                 3.0                 4.75
# 1  2015                2.50                 4.0                 2.00
# 2  2016                3.50                 2.5                 3.00
# 3  2017                4.00                 2.0                 3.50
# 4  2018                1.50                 4.5                 1.00
